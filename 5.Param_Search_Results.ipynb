# %%
import pandas as pd

# %%
results = pd.read_csv('results.csv')

# %%
results
# Out:
#     Unnamed: 0  EMBED_OUTPUT_DIM  USE_SPATIAL_DROPOUT  SPATIAL_DROPOUT  \
# 0            0                 8                False              0.0
# 1            0                 8                False              0.0
# 2            0                 8                False              0.0
# 3            0                 8                False              0.0
# 4            0                 8                False              0.0
# 5            0                 8                False              0.0
# 6            0                 8                False              0.0
# 7            0                 8                False              0.0
# 8            0                 8                False              0.0
# 9            0                 8                False              0.0
# 10           0                 8                False              0.0
# 11           0                 8                False              0.0
# ...
