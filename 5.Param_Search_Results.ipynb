# %%
import pandas as pd
results = pd.read_csv('results.csv')
print(results.shape)
results = results[results.DATA_SIZE > 100]
results.sort_values(by=['mae'], ascending=True)
# Out:
# (40, 21)
#     Unnamed: 0  EMBED_OUTPUT_DIM  USE_SPATIAL_DROPOUT  SPATIAL_DROPOUT  \
# 39           0               346                 True         0.090000
# 33           0                 8                False         0.000000
# 34           0                 8                False         0.068522
# 35           0                 8                False         0.070000
# 36           0                 8                False         0.070000
# 37           0               346                 True         0.090000
# 38           0                 8                False         0.070000
#
#    RNN_TYPE  RNN_LAYER_COUNT  RNN_OUT  RNN_DROPOUT  RECURRENT_DROPOUT  \
# 39     LSTM                2       83     0.260000           0.070000
# 33     LSTM                1        8     0.000000           0.000000
# 34      GRU                1      140     0.114035           0.061466
# 35      GRU                1      140     0.110000           0.060000
# 36      GRU                1      140     0.110000           0.060000
# 37     LSTM                2       83     0.260000           0.070000
# 38      GRU                1      140     0.110000           0.060000
#
#     BATCH_SIZE  ...  EPOCH  DATA_SIZE  METRIC      loss       mae       acc  \
# 39         225  ...      4     102739   funny  0.043851  0.194133  0.000000
# 33          64  ...      1       1000   stars  0.103809  0.290430  0.448485
# 34         109  ...      4      10000   stars       NaN       NaN  0.000000
# 35         109  ...      4      10000   stars       NaN       NaN  0.000000
# 36         109  ...      4      10000   funny       NaN       NaN  0.000000
# 37         225  ...      4      10000   funny       NaN       NaN  0.000000
# 38         109  ...      4     172032   funny       NaN       NaN  0.000000
#
#       fit_time                        model_uuid                   timestamp  \
# 39  522.575278  3c422470a97040a689063e9d957eaed2  2019-08-05T01:00:44.101295
# 33   15.431247  ec1110b07f0f4fc991b31990e4d8617c  2019-08-04T21:05:32.768751
# 34  464.391482  42e568301c0b4a7e96b47188ffee05b3  2019-08-04T22:51:45.904441
# 35  469.559443  b59fee58f5334820b68f7be7ffee83aa  2019-08-04T23:38:03.426783
# 36  468.078126  62a7b63b1a744419a99287e5ce10e99c  2019-08-04T23:56:19.517189
# 37  735.206953  72fafe19b7d3410188e5a6987dc55726  2019-08-05T00:11:36.586643
# 38  287.439706  2ff141c69f6d4e9aaa7b4851c5b04c14  2019-08-05T00:49:50.918279
#
#    bayes_metric
# 39    19.796685
# 33   146.879992
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
#
# [7 rows x 21 columns]

# %% [markdown]
# # Correlation Analys

# %%
corr = results.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(results)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     343     try:
# --> 344         dt = signed_to_unsigned[dt.type]
#     345     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-7b4d481bb168> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.pairplot(results)
#       4 plt.show()
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2640         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2641         color=color, label=label, stacked=stacked, normed=normed,
# -> 2642         **({"data": data} if data is not None else {}), **kwargs)
#    2643
#    2644
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6765             # this will automatically overwrite bins,
#    6766             # so that each histogram uses the same bins
# -> 6767             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6768             m = m.astype(float)  # causes problems later if it's an int
#    6769             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     813
#     814         # Pre-compute histogram scaling factor
# --> 815         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     816
#     817         # We iterate over blocks here for two reasons: the first is that for
#
# ~/anaconda3/envs/Yelp_NLP/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     344         dt = signed_to_unsigned[dt.type]
#     345     except KeyError:
# --> 346         return np.subtract(a, b, dtype=dt)
#     347     else:
#     348         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
import numpy as np
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, 
            mask=np.zeros_like(corr, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, 
            ax=ax)
plt.show()
